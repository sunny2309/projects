# %%
import requests
import json
import pandas as pd
import datetime
import numpy as np

pd.set_option("display.max_columns", 500)
pd.set_option("display.max_rows", 500)

# %%
api_key = 'ce8a7a3822ea3fad7e349054d6bbae6b'
url = 'https://financialmodelingprep.com/api/v3/historical/sp500_constituent?apikey={}'.format(api_key)

sdate_dt = datetime.date(2010, 1, 1)
edate_dt = datetime.datetime.today().date()

# %%
# Grab historical S&P500 holdings from FMP
out = requests.get(url)

# %%
# Save as dataframe
df = pd.DataFrame(out.json())

# %%
# Convert date column to index and save as new index
df.index = pd.DatetimeIndex(df.dateAdded)

# %%
# Sort by dateAdded index and drop old string dateAdded column
df = df.sort_index().drop(columns = ['dateAdded'])

# %%
# Filter by desired daterange and isolate all unique symbols
tickers = list(set( df['symbol'].values ))

# %%
# Create a results dataframe that has the entire date range as the index and all possible tickers as the columns
df_sp500 = pd.DataFrame(index = pd.date_range('19941230', datetime.datetime.today().date().strftime('%Y%m%d')), columns = tickers)

# %%
df_sp500
# Out:
#             FBO  JOY  WBA  PKG CPRT  CEN  RCL FANG  MLM  ABT SNPS CARS CARR  \
# 1994-12-30  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1994-12-31  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1995-01-01  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1995-01-02  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1995-01-03  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...         ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 2020-11-01  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2020-11-02  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2020-11-03  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2020-11-04  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2020-11-05  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# ...

# %%
# %%time

for symbol in df_sp500.columns:
    intermediate_df = df[df.symbol == symbol]
    #print(symbol, intermediate_df.shape[0])
    if intermediate_df.shape[0] > 0:
        
        ## Logic to Find Addition & Removal Date Sequence
        ticker_dates = {"ADD": None, "REMOVE": None}
        date_seq = []
        for row in intermediate_df.iterrows():
            if row[1].removedTicker:
                ticker_dates["REMOVE"] = row[1].date
            else:
                ticker_dates["ADD"] = row[1].date
            if ticker_dates["ADD"] and ticker_dates["REMOVE"]:
                date_seq.append((ticker_dates["ADD"], ticker_dates["REMOVE"]))
                ticker_dates["ADD"] = None
                ticker_dates["REMOVE"] = None
        if ticker_dates["ADD"]:
            date_seq.append((ticker_dates["ADD"], None))
            ticker_dates["ADD"] = None
        
        ## Logic to Fill dataframe based on Addition & Removal Dates
        for start_dt, end_dt in date_seq:
            if end_dt:
                df_sp500.loc[start_dt:end_dt, symbol] = True
            else:
                end_dt = str(df_sp500.index[-1]).split(" ")[0]
                df_sp500.loc[start_dt:end_dt, symbol] = True
# Out:
# CPU times: user 4min 23s, sys: 38.5 s, total: 5min 1s
# Wall time: 5min 1s

# %%
## This is special case. In this case we are using second row as starting date.
## Please confirm whether its good decision else I'll put condition which will use first row as startng date

temp = df[df.symbol == "WM"]
temp
# Out:
#                    addedSecurity removedTicker       removedSecurity  \
# dateAdded
# 1997-07-01  Waste Management Inc
# 1998-07-16  Waste Management Inc
# 2008-09-29                                  WM  Waste Management Inc
#
#                   date                         reason symbol
# dateAdded
# 1997-07-01  1997-07-01  Market capitalization change.     WM
# 1998-07-16  1998-07-16  Market capitalization change.     WM
# 2008-09-29  2008-09-29   Market capitalization change     WM

# %%
df_sp500["1998-07-16":"2008-09-29"]["WM"]
# Out:
# 1998-07-16    True
# 1998-07-17    True
# 1998-07-18    True
# 1998-07-19    True
# 1998-07-20    True
#               ...
# 2008-09-25    True
# 2008-09-26    True
# 2008-09-27    True
# 2008-09-28    True
# 2008-09-29    True
# Freq: D, Name: WM, Length: 3729, dtype: object

# %%
# Create a results dataframe that has the entire date range as the index and all possible tickers as the columns
df_sp500 = pd.DataFrame(index = pd.date_range('19941230', datetime.datetime.today().date().strftime('%Y%m%d')), columns = tickers)
df_sp500
# Out:
#             FBO  JOY  WBA  PKG CPRT  CEN  RCL FANG  MLM  ABT SNPS CARS CARR  \
# 1994-12-30  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1994-12-31  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1995-01-01  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1995-01-02  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1995-01-03  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...         ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 2020-11-01  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2020-11-02  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2020-11-03  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2020-11-04  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2020-11-05  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# ...

# %%
# %%time

for symbol in df_sp500.columns:
    intermediate_df = df[df.symbol == symbol]
    #print(symbol, intermediate_df.shape[0])
    if intermediate_df.shape[0] > 0:
        
        ## Logic to Find Addition & Removal Date Sequence
        ticker_dates = {"ADD": None, "REMOVE": None}
        date_seq = []
        for row in intermediate_df.iterrows():
            if row[1].removedTicker:
                ticker_dates["REMOVE"] = row[1].date
            else:
                ticker_dates["ADD"] = row[1].date
            if ticker_dates["ADD"] and ticker_dates["REMOVE"]:
                date_seq.append((ticker_dates["ADD"], ticker_dates["REMOVE"]))
                ticker_dates["ADD"] = None
                ticker_dates["REMOVE"] = None
        if ticker_dates["ADD"]:
            date_seq.append((ticker_dates["ADD"], None))
            ticker_dates["ADD"] = None
            
        ser = pd.Series([np.nan]*df_sp500.shape[0], index=df_sp500.index)
        ## Logic to Fill dataframe based on Addition & Removal Dates
        for start_dt, end_dt in date_seq:
            if end_dt:
                ser.loc[start_dt:end_dt] = True
            else:
                end_dt = str(df_sp500.index[-1]).split(" ")[0]
                ser.loc[start_dt:end_dt] = True
                
        df_sp500[symbol] = ser.values
# Out:
# CPU times: user 10.3 s, sys: 3.97 s, total: 14.2 s
# Wall time: 14.2 s

# %%
df_sp500["1998-07-15":"2008-09-30"]["WM"]
# Out:
# 1998-07-15     NaN
# 1998-07-16    True
# 1998-07-17    True
# 1998-07-18    True
# 1998-07-19    True
#               ...
# 2008-09-26    True
# 2008-09-27    True
# 2008-09-28    True
# 2008-09-29    True
# 2008-09-30     NaN
# Freq: D, Name: WM, Length: 3731, dtype: object

# %%
df_sp500["2000-07-27":"2002-08-15"]["PALM"]
# Out:
# 2000-07-27     NaN
# 2000-07-28    True
# 2000-07-29    True
# 2000-07-30    True
# 2000-07-31    True
#               ...
# 2002-08-11    True
# 2002-08-12    True
# 2002-08-13    True
# 2002-08-14    True
# 2002-08-15     NaN
# Freq: D, Name: PALM, Length: 750, dtype: object

# %%
df_sp500["2002-01-29":"2015-07-03"]["MWV"]
# Out:
# 2002-01-29     NaN
# 2002-01-30    True
# 2002-01-31    True
# 2002-02-01    True
# 2002-02-02    True
#               ...
# 2015-06-29    True
# 2015-06-30    True
# 2015-07-01    True
# 2015-07-02    True
# 2015-07-03     NaN
# Freq: D, Name: MWV, Length: 4904, dtype: object

# %%
df_sp500["1998-07-16":"2008-09-29"]["WM"]
# Out:
# 1998-07-16    True
# 1998-07-17    True
# 1998-07-18    True
# 1998-07-19    True
# 1998-07-20    True
#               ...
# 2008-09-25    True
# 2008-09-26    True
# 2008-09-27    True
# 2008-09-28    True
# 2008-09-29    True
# Freq: D, Name: WM, Length: 3729, dtype: object
