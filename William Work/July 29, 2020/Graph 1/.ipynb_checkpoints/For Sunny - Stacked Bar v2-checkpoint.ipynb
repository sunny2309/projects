# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import rc
from mpl_toolkits.axes_grid.axislines import Subplot

import math
from matplotlib.ticker import FuncFormatter

# %%
df = pd.read_csv('stacked_bar_df.csv', index_col = 0)

# %%
r = [x for x in range(0, len(list(df.index)), 1)]

# %%
len(list(df.index))
# Out:
# 16

# %%
df = df.sort_values('occurences_total', ascending = False)

top_10 = [x for x in df['percent_top_10_occurences']]

the_rest = [x for x in df['percent_the_rest_occurences']]


mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False

colors = ['#c2c2f0','#ffb3e6']
colors2 = ['#f9bc86', '#a3acff']

plt.figure(figsize = (30,10))

barWidth = 0.85
names = tuple((list(df.index)))

ax = plt.bar(r, top_10, bottom = the_rest, label = 'Top 10 Titles', width = barWidth, color = colors2[0])
ax2 = plt.bar(r, the_rest, label = '"The Rest"', edgecolor='white', width = barWidth, color = colors2[1])

# Custom x axis
plt.xticks(r, names, fontsize = 25, rotation = 25)
plt.yticks(fontsize = 25)
plt.ylabel('Total Est. Viewership (TV Shows + Movies)', fontsize = 22)
plt.title('Concentration of 10 Most Popular Titles', fontsize=35)
plt.legend(fontsize = 25, title = '% Viewership Share', title_fontsize = '25') # prop={'size': 25},
plt.grid(False)
plt.subplots_adjust(left=0, bottom=0, right=.7, top=1, wspace=5, hspace=5)
plt.tight_layout()
plt.savefig('stacked_bar_top_occurences.png')

# %%
df
# Out:
#                   occurences_total  occurences_top_10  occurences_the_rest  \
# Warner Brothers         95728777.0         26709158.0           69019619.0
# Viacom                  87798035.0         27271367.0           60526668.0
# Disney                  75103122.0         28916442.0           46186680.0
# NBC Universal           68876141.0         19508658.0           49367483.0
# 20th Century Fox        51925253.0         13700348.0           38224905.0
# Sony                    44516972.0         18678818.0           25838154.0
# Netflix                 43627019.0         20028479.0           23598540.0
# HBO                     23040131.0         17322319.0            5717812.0
# Lionsgate               18706597.0          8768609.0            9937988.0
# AMC                     12804811.0         10041246.0            2763565.0
# Amazon                   7328015.0          4017787.0            3310228.0
# A&E Networks             6312942.0          5687296.0             625646.0
# Discovery                4227148.0          1604018.0            2623130.0
# Hulu                     4006013.0          3539211.0             466802.0
# MGM                      3945242.0          1964363.0            1980879.0
# Apple TV+                1764470.0          1673384.0              91086.0
#
#                   percent_top_10  percent_the_rest  total_titles  \
# Warner Brothers         0.279009          0.720991        1370.0
# Viacom                  0.310615          0.689385        1652.0
# Disney                  0.385023          0.614977         778.0
# NBC Universal           0.283243          0.716757        1293.0
# 20th Century Fox        0.263847          0.736153        1066.0
# Sony                    0.419589          0.580411        1262.0
# Netflix                 0.459084          0.540916         613.0
# HBO                     0.751832          0.248168         232.0
# Lionsgate               0.468744          0.531256         752.0
# AMC                     0.784178          0.215822         330.0
# Amazon                  0.548278          0.451722         122.0
# A&E Networks            0.900895          0.099105          89.0
# Discovery               0.379456          0.620544         294.0
# Hulu                    0.883475          0.116525          45.0
# MGM                     0.497907          0.502093         400.0
# Apple TV+               0.948378          0.051622          22.0
#
#                   percent_top_10_occurences  percent_the_rest_occurences  \
# Warner Brothers                  26709158.0                   69019619.0
# Viacom                           27271367.0                   60526668.0
# Disney                           28916442.0                   46186680.0
# NBC Universal                    19508658.0                   49367483.0
# 20th Century Fox                 13700348.0                   38224905.0
# Sony                             18678818.0                   25838154.0
# Netflix                          20028479.0                   23598540.0
# HBO                              17322319.0                    5717812.0
# Lionsgate                         8768609.0                    9937988.0
# AMC                              10041246.0                    2763565.0
# Amazon                            4017787.0                    3310228.0
# A&E Networks                      5687296.0                     625646.0
# Discovery                         1604018.0                    2623130.0
# Hulu                              3539211.0                     466802.0
# MGM                               1964363.0                    1980879.0
# Apple TV+                         1673384.0                      91086.0
#
#                   percent_total
# Warner Brothers        0.174144
# Viacom                 0.159717
# Disney                 0.136623
# NBC Universal          0.125295
# 20th Century Fox       0.094459
# Sony                   0.080983
# Netflix                0.079364
# HBO                    0.041913
# Lionsgate              0.034030
# AMC                    0.023294
# Amazon                 0.013331
# A&E Networks           0.011484
# Discovery              0.007690
# Hulu                   0.007287
# MGM                    0.007177
# Apple TV+              0.003210

# %%
ax = df.plot.bar(y=["occurences_top_10", "occurences_the_rest"], 
                 stacked=True,
                 figsize=(30,12), 
                 width=0.85,
                 rot=90, 
                 color=colors2, #["tomato", "lime"],
                )

plt.legend(labels=["Top 10 Titles",'"The Rest"'], 
           fontsize = 25, 
           title = '% Viewership Share', title_fontsize = 25);

for i, (percent, tot) in enumerate(df[["percent_top_10", "occurences_total"]].values):
    plt.text(i, tot, "%.2f%%"%(percent*100), fontsize=22, ha="center", va="bottom")

plt.xticks(fontsize = 25)

def millions(x, pos):
    return '%1.1fM' % (x * 1e-6)

plt.yticks(fontsize = 25)
ax.yaxis.set_major_formatter(FuncFormatter(millions))
plt.ylabel('Total Est. Viewership\n(TV Shows + Movies)', fontsize = 25)

plt.title('Concentration of 10 Most Popular Titles', fontsize=35)
plt.subplots_adjust(left=0, bottom=0, right=.7, top=1, wspace=5, hspace=5)
plt.tight_layout()
plt.savefig('stacked_bar_top_occurences.png', dpi=200);

# %%
ax = df.plot.bar(y="occurences_total", 
                 #stacked=True,
                 figsize=(30,10), 
                 width=0.90,
                 rot=90, 
                 color=colors2[1], #["tomato", "lime"],
                )
                 #alpha=0.5)

plt.legend(labels=["Total Occurences"], 
           fontsize = 25, 
           title = 'Viewership Share', 
           title_fontsize = 25);

for i, (percent, tot) in enumerate(df[["percent_top_10", "occurences_total"]].values):
    plt.text(i, tot, "%.2f%%"%(percent*100), fontsize=22, ha="center", va="bottom")

plt.xticks(fontsize = 25)

def millions(x, pos):
    return '%1.1fM' % (x * 1e-6)

plt.yticks(fontsize = 25)
ax.yaxis.set_major_formatter(FuncFormatter(millions))
plt.ylabel('Total Est. Viewership \n(TV Shows + Movies)', fontsize = 22)

plt.title('Concentration of 10 Most Popular Titles', fontsize=35);
